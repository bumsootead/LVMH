# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# data load

data = pd.read_csv('Data/LV.csv')

# target is continuous volume -> regression

y_data = data['Volume'].values
print("Sample volumes:", y_data[:20])

x_data = data[['Open', 'High', 'Low', 'Close']]
print("Sample features:", x_data.head(1))

# normalize features
scaler = StandardScaler()
x_data_normalized = scaler.fit_transform(x_data)
print("Normalized feature sample:", x_data_normalized[:1])

#  Creating Machine Learning model with LVMH stock volume
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Data Split
X_train, X_test, y_train, y_test = train_test_split(
    x_data_normalized, y_data, test_size=0.2, random_state=42)

# LVMH volume prediction using RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Model Analysis

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"MSE: {mse:.4f}, R2: {r2:.4f}")

# Model save
import joblib
joblib.dump(model, "volume_model.pkl")
print("Model saved to volume_model.pkl")
# Out:
# Sample volumes: [ 615855 1691700 1563735 1641215 1360530 2381515 1157955 1444595 1356875
#  1059010  834585  927620  747945 1666055 1833120  824065  592380  534475
#  1080090  629910]
# Sample features:         Open       High        Low      Close
# 0  56.738157  57.603634  54.525009  54.895931
# Normalized feature sample: [[-0.67425569 -0.67320909 -0.68093968 -0.68257303]]
# MSE: 296993952410.7345, R2: 0.3978
# Model saved to volume_model.pkl
